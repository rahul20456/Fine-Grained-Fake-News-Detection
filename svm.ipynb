# %%
# !pip install vaderSentiment
# !pip install autocorrect
# !pip install nltk
# !pip install typing 
# !pip install vaderSentiment
# !pip install transformers
# !pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 12.2 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 622 kB 19.2 MB/s
# ...
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622381 sha256=2a05fbe0c561ff8f533bb6c5e75a1805efe2ac5bcb6a3e71e78fe0995420abc8
#   Stored in directory: /root/.cache/pip/wheels/72/b8/3b/a90246d13090e85394a8a44b78c8abf577c0766f29d6543c75
# Successfully built autocorrect
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 78 kB 3.5 MB/s
# ...

# %%
# import arcpy
import pandas as pd
import numpy as np
from zipfile import ZipFile
import os
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from wordcloud import STOPWORDS, WordCloud
import re
import csv
import copy
import pandas as pd
import nltk
import pandas as pd
import nltk
import string
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud
import matplotlib.pyplot  as plt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.metrics.distance import jaccard_distance
from nltk.util import ngrams
from textblob import TextBlob
from textblob import Word
from autocorrect import Speller
from nltk.corpus import stopwords
import pickle
import pandas as pd
import re
import nltk
import numpy as np
from pathlib import Path
import itertools
import string
import random
import time
from typing import List
import string
import math
from typing import List
from collections import defaultdict
from sklearn.pipeline import Pipeline
from collections import Counter
from numpy.random import choice
from pathlib import Path
import string
from functools import reduce
from math import log
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
nltk.download('punkt')
from nltk.corpus import brown
nltk.download('brown')

nltk.download('punkt')
import matplotlib.pyplot  as plt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import transformers
from transformers import AutoModel, BertTokenizerFast
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import pandas as pd
import numpy as np
import csv
import spacy
from scipy import stats
from sklearn import linear_model
import io

from sentence_transformers import SentenceTransformer, losses, models, util
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator
from sentence_transformers.readers import InputExample
from sentence_transformers import SentenceTransformer, models
import torch 
from torch.utils.data import DataLoader
import gzip
import gensim 
import logging
from gensim.models import Word2Vec 
from gensim.test.utils import common_texts
from gensim.models import KeyedVectors
from gensim import models
import nltk
from gensim.models import word2vec
from nltk.corpus import brown
import logging
from sklearn.svm import SVR
import scipy.stats
import torch.nn as nn
from sklearn.metrics import f1_score

# %%
df_test = pd.read_csv('/content/F3_FineGrained_Fake_News_Detection_test.csv')
df_train = pd.read_csv('/content/F3_FineGrained_Fake_News_Detection_train.csv')

# %%
# df_test.head()
# Out:
#                                            statement  \
# 0  In the last six years of Ciancis administratio...
# 1  The (health reform) legislation which Washingt...
# 2  Says Donald Trump and Marco Rubio opposed Cruz...
# 3  Says the United States has the highest corpora...
# 4  Before President Obama acted in Libya in 2011,...
#
#                                 subject          speaker  \
# 0  crime,criminal-justice,public-safety     jorge-elorza
# 1                   economy,health-care      rob-portman
# 2               abortion,federal-budget         ted-cruz
# 3                    corporations,taxes  joseph-kyrillos
# 4       foreign-policy,military,pundits        karl-rove
#
#        speakers job title    state info party affiliation  id
# 0           Law professor  Rhode Island          democrat   0
# 1  U.S. senator from Ohio          Ohio        republican   1
# 2                 Senator         Texas        republican   2
# ...

# %%
# df_train.head()
# Out:
#          label                                          statement  \
# 0        false  The Iranians continue in the view of every obj...
# 1  mostly-true  The city of Columbus would save $41 million a ...
# 2        false  Says, The Democrats proposed budget is also ba...
# 3  barely-true  Health insurance costs for Floridians are up 3...
# 4        false  At Texas AM University, only 49 out of 3,000 f...
#
#                               subject                   speaker  \
# 0                      foreign-policy               john-mccain
# 1                   jobs,labor,unions                 dave-yost
# 2  pensions,state-budget,taxes,unions               bruce-hanna
# 3                         health-care  republican-party-florida
# 4                           education                dick-armey
#
#                                   speakers job title state info  \
# 0                                       U.S. senator    Arizona
# ...

# %%
# df_train.describe()
# Out:
#                 id
# count  7168.000000
# mean   3583.500000
# std    2069.367697
# min       0.000000
# 25%    1791.750000
# 50%    3583.500000
# 75%    5375.250000
# max    7167.000000

# %%
# df_train.shape
# Out:
# (7168, 8)

# %%
# df_train.columns
# Out:
# Index(['label', 'statement', 'subject', 'speaker', 'speakers job title',
#        'state info', 'party affiliation', 'id'],
#       dtype='object')

# %%
# df_train
# Out:
#             label                                          statement  \
# 0           false  The Iranians continue in the view of every obj...
# 1     mostly-true  The city of Columbus would save $41 million a ...
# 2           false  Says, The Democrats proposed budget is also ba...
# 3     barely-true  Health insurance costs for Floridians are up 3...
# 4           false  At Texas AM University, only 49 out of 3,000 f...
# ...           ...                                                ...
# 7163        false  Says we could have saved ourselves the cost of...
# 7164         true  In Virginia, Medicaid has grown by 1,600 perce...
# 7165         true  Before 2005, the percentage of Texas high scho...
# 7166  mostly-true  New Jersey has had seven credit downgrades sin...
# 7167         true  In July 1996, Mitt Romney helped locate the mi...
#
#                                                 subject  \
# 0                                        foreign-policy
# ...

# %%
# df_train.label.unique()
# Out:
# array(['false', 'mostly-true', 'barely-true', 'true', 'half-true',
#        'pants-fire'], dtype=object)

# %%
df_train['label'] = df_train['label'].replace('false',1)
df_train['label'] = df_train['label'].replace('mostly-true',4)
df_train['label'] = df_train['label'].replace('barely-true',2)
df_train['label'] = df_train['label'].replace('true',5)
df_train['label'] = df_train['label'].replace('half-true',3)
df_train['label'] = df_train['label'].replace('pants-fire',0)

# %%
# df_train.label.dtype
# Out:
# dtype('int64')

# %%
# df_test['label'] = df_test['label'].replace('false',1)
# df_test['label'] = df_test['label'].replace('mostly-true',2)
# df_test['label'] = df_test['label'].replace('barely-true',3)
# df_test['label'] = df_test['label'].replace('true',4)
# df_test['label'] = df_test['label'].replace('half-true',5)
# df_test['label'] = df_test['label'].replace('pants-fire',6)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# x_train,x_valid,y_train,y_valid=train_test_split(df_train['label'],df_train[['statement', 'subject', 'speaker', 'speakers job title',
#        'state info', 'party affiliation']],test_size=.2,random_state=20)

# %%
df_train.columns
# Out:
# Index(['label', 'statement', 'subject', 'speaker', 'speakers job title',
#        'state info', 'party affiliation', 'id'],
#       dtype='object')

# %%
# df_train[['statement', 'subject', 'speaker', 'speakers job title',
      #  'state info', 'party affiliation', 'id']]
# Out:
#                                               statement  \
# 0     The Iranians continue in the view of every obj...
# 1     The city of Columbus would save $41 million a ...
# 2     Says, The Democrats proposed budget is also ba...
# 3     Health insurance costs for Floridians are up 3...
# 4     At Texas AM University, only 49 out of 3,000 f...
# ...                                                 ...
# 7163  Says we could have saved ourselves the cost of...
# 7164  In Virginia, Medicaid has grown by 1,600 perce...
# 7165  Before 2005, the percentage of Texas high scho...
# 7166  New Jersey has had seven credit downgrades sin...
# 7167  In July 1996, Mitt Romney helped locate the mi...
#
#                                                 subject  \
# 0                                        foreign-policy
# 1                                     jobs,labor,unions
# 2                    pensions,state-budget,taxes,unions
# 3                                           health-care
# ...

# %%
y_train
# Out:
#                                               statement  \
# 4486  Under former President George W. Bushs adminis...
# 2817  We closed that plant down. It was a $27 millio...
# 843   There have been multiple media reports about (...
# 4743  We admit about 100,000 permanent immigrants fr...
# 1218  Charlie Crist has six different positions on O...
# ...                                                 ...
# 1428  Says $1,100 of the tuition paid by every Orego...
# 6537  Georgia has the 9th highest rate of adults, ag...
# 7068  In Russia all people are absolutely equal rega...
# 4367  We had a massive landslide victory, as you kno...
# 2522  John McCain "voted against the Bush tax cuts, ...
#
#                                      subject  \
# 4486  bush-administration,economy,jobs,labor
# 2817                   education,environment
# 843               candidates-biography,crime
# 4743                             immigration
# 1218                             health-care
# ...

# %%
# x_valid
# Out:
# 3448    1
# 2233    5
# 2355    4
# 2221    2
# 1848    3
#        ..
# 2248    6
# 6272    5
# 71      1
# 2348    2
# 5127    3
# Name: label, Length: 1434, dtype: int64

# %%
# df_train.isnull().sum().sum()
# Out:
# 3582

# %%
# df_train.columns
# Out:
# Index(['label', 'statement', 'subject', 'speaker', 'speakers job title',
#        'state info', 'party affiliation', 'id'],
#       dtype='object')

# %%
# df_train['label'].isnull().sum()
# Out:
# 0

# %%
# df_train['statement'].isnull().sum()
# Out:
# 0

# %%
df_train[df_train['subject'].isnull()]
# Out:
#       label                                          statement subject  \
# 4620      1  The fact is that although we have had a presid...     NaN
#
#      speaker speakers job title state info party affiliation    id
# 4620     NaN                NaN        NaN               NaN  4620

# %%
df_train[df_train['speaker'].isnull()]
# Out:
#       label                                          statement subject  \
# 4620      1  The fact is that although we have had a presid...     NaN
#
#      speaker speakers job title state info party affiliation    id
# 4620     NaN                NaN        NaN               NaN  4620

# %%
# df_train['speakers job title'].isnull().sum()
# Out:
# 2021

# %%
# df_train['state info'].isnull().sum()
# Out:
# 1558

# %%
df_train[df_train['party affiliation'].isnull()]
# Out:
#       label                                          statement subject  \
# 4620      1  The fact is that although we have had a presid...     NaN
#
#      speaker speakers job title state info party affiliation    id
# 4620     NaN                NaN        NaN               NaN  4620

# %%
bad_df = df_train.index.isin([4620])

# %%
df_train1=df_train[~bad_df]

# %%
df_train1
# Out:
#       label                                          statement  \
# 0         1  The Iranians continue in the view of every obj...
# 1         2  The city of Columbus would save $41 million a ...
# 2         1  Says, The Democrats proposed budget is also ba...
# 3         3  Health insurance costs for Floridians are up 3...
# 4         1  At Texas AM University, only 49 out of 3,000 f...
# ...     ...                                                ...
# 7163      1  Says we could have saved ourselves the cost of...
# 7164      4  In Virginia, Medicaid has grown by 1,600 perce...
# 7165      4  Before 2005, the percentage of Texas high scho...
# 7166      2  New Jersey has had seven credit downgrades sin...
# 7167      4  In July 1996, Mitt Romney helped locate the mi...
#
#                                                 subject  \
# 0                                        foreign-policy
# 1                                     jobs,labor,unions
# ...

# %%
# label1=df_train1.label

# %%
# # x_train,x_valid,y_train,y_valid=train_test_split(df_train1[['statement', 'subject', 'speaker', 
# #         'party affiliation']],df_train1['label'],test_size=.2,random_state=20)
# x_train,x_valid,y_train,y_valid=train_test_split(df_train1['statement'],label1,test_size=.2,random_state=20)

# %%
# vector=TfidfVectorizer(stop_words='english',max_df=1)

# %%
# tf_train=vector.fit_transform(x_train)
# tf_test=vector.transform(x_valid)

# %%
# x_train,x_valid,y_train,y_valid=train_test_split(df_train1[['statement', 'subject', 'speaker', 
#         'party affiliation']],df_train1['label'],test_size=.2,random_state=20)

# %%
# from sklearn.linear_model import PassiveAggressiveClassifier
# pac = PassiveAggressiveClassifier(max_iter=50)
# pac.fit(tf_train, y_train)
# Out:
# PassiveAggressiveClassifier(max_iter=50)

# %%
# tf_train
# Out:
# <5733x4496 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4496 stored elements in Compressed Sparse Row format>

# %%
# predicton the tst dataset
from sklearn.metrics import accuracy_score, confusion_matrix
# y_pred = pac.predict(tf_test)

# %%
# score = accuracy_score(y_valid, y_pred)

# %%
score
# Out:
# 0.1799163179916318

# %%
score
# Out:
# 0.1806136680613668

# %%
device = torch.device("cuda")
device
# Out:
# device(type='cuda')

# %%
from sklearn.metrics import f1_score

# %%
sc1=f1_score(y_valid,y_pred,average='macro')

# %%
sc1
# Out:
# 0.12481675199271038

# %%
def get_feature_model2(data_frame):
  """
  Input a data frame and return the embedding vectors for the each sentence column using model2,
  Return 2 matrices each of shape (#_samples, #size_of_word_emb).
  """
  model1 = SentenceTransformer('all-MiniLM-L6-v2')
  embeddings1 = model1.encode(data_frame['sent_a'], convert_to_tensor=False)
  embeddings2 = model1.encode(data_frame['sent_b'], convert_to_tensor=False)
  return embeddings1,embeddings2

# %%
df_train1.reset_index()
# Out:
#       index  label                                          statement  \
# 0         0      1  The Iranians continue in the view of every obj...
# 1         1      4  The city of Columbus would save $41 million a ...
# 2         2      1  Says, The Democrats proposed budget is also ba...
# 3         3      2  Health insurance costs for Floridians are up 3...
# 4         4      1  At Texas AM University, only 49 out of 3,000 f...
# ...     ...    ...                                                ...
# 5344   5345      0  Says Donald Trumps Make America Great Againhat...
# 5345   5346      3             Light rail does not reduce congestion.
# 5346   5347      4  Here are the stats: Per population, we kill ea...
# 5347   5348      5       Ive taken on the federal government and won.
# 5348   5349      4  Were now spending 42 percent of our economy on...
#
#                                            subject                   speaker  \
# ...

# %%
# df_train1.columns
# Out:
# Index(['label', 'statement', 'subject', 'speaker', 'speakers job title',
#        'state info', 'party affiliation', 'id'],
#       dtype='object')

# %%
df_train2=df_train1[['label', 'statement', 'subject', 'speaker','party affiliation' ]]

# %%
df_train2
# Out:
#       label                                          statement  \
# 0         1  The Iranians continue in the view of every obj...
# 1         2  The city of Columbus would save $41 million a ...
# 2         1  Says, The Democrats proposed budget is also ba...
# 3         3  Health insurance costs for Floridians are up 3...
# 4         1  At Texas AM University, only 49 out of 3,000 f...
# ...     ...                                                ...
# 7163      1  Says we could have saved ourselves the cost of...
# 7164      4  In Virginia, Medicaid has grown by 1,600 perce...
# 7165      4  Before 2005, the percentage of Texas high scho...
# 7166      2  New Jersey has had seven credit downgrades sin...
# 7167      4  In July 1996, Mitt Romney helped locate the mi...
#
#                                                 subject  \
# 0                                        foreign-policy
# 1                                     jobs,labor,unions
# ...

# %%
def get_feature_model2(data_frame):
  """
  Input a data frame and return the embedding vectors for the each sentence column using model2,
  Return 2 matrices each of shape (#_samples, #size_of_word_emb).
  """
  model1 = SentenceTransformer('all-MiniLM-L6-v2')
  embeddings1 = model1.encode(data_frame['statement'], convert_to_tensor=False)
  embeddings2 = model1.encode(data_frame['subject'], convert_to_tensor=False)
  embeddings3 = model1.encode(data_frame['speaker'], convert_to_tensor=False)
  embeddings4 = model1.encode(data_frame['party affiliation'], convert_to_tensor=False)
  return embeddings1,embeddings2,embeddings3,embeddings4

# %%
# feature_1_dev1, feature_2_dev1,feature_3_dev1, feature_4_dev1,feature_5_dev1 = get_feature_model2(df_dev)
# feature_1_train1, feature_2_train1 = get_feature_model2(df_train)
# # feature_1_test1, feature_2_test1 = get_feature_model2(df_test)

# %%
df_train3 = df_train2.sample(frac=1, axis=1).sample(frac=1).reset_index(drop=True)

# %%
df_train3
# Out:
#       label                                          statement  \
# 0         5  Says Bruce Starr voted to throw 6,000 Oregonia...
# 1         1  The proposed Gogebic iron ore mine is just up ...
# 2         5  Solyndrahad robots that whistled Disney songs....
# 3         2  With the tax controls we already put in place,...
# 4         5  In this city, there hasnt been a stadium thats...
# ...     ...                                                ...
# 7162      6  Newt Gingrich says electric co-ops and credit ...
# 7163      4  Hillary Clintons State Department sent three c...
# 7164      5  Forty percent of the Fortune 500 were started ...
# 7165      2  The Fulton County vote count will be finished ...
# 7166      4  In Malaysia many of the workers are indentured...
#
#                                             subject                  speaker  \
# 0                                           workers  democratic-party-oregon
# ...

# %%
le=len(df_train2)
le
# Out:
# 5349

# %%
df_train4=df_train2[0:int(0.8*le)]
df_dev4=df_train2[int(0.8*le):le]
df_dev4=df_dev4.reset_index(drop=True)
df_train4=df_train4.reset_index(drop=True)

# %%
feature_1_dev1, feature_2_dev1,feature_3_dev1, feature_4_dev1 = get_feature_model2(df_dev4)
feature_1_train1, feature_2_train1,feature_3_train1, feature_4_train1 = get_feature_model2(df_train4)
# # feature_1_test1, feature_2_test1 = get_feature_model2(df_test)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
df_train4
# Out:
#       label                                          statement  \
# 0         1  The Iranians continue in the view of every obj...
# 1         2  The city of Columbus would save $41 million a ...
# 2         1  Says, The Democrats proposed budget is also ba...
# 3         3  Health insurance costs for Floridians are up 3...
# 4         1  At Texas AM University, only 49 out of 3,000 f...
# ...     ...                                                ...
# 5729      3  Sen. Robert Bennett, R-Utah, cast votes for TA...
# 5730      3  John McCain's health care plan "leaves you on ...
# 5731      5  Not one tax has been raised since Ive been gov...
# 5732      5  America has lost over 50,000 manufacturing fac...
# 5733      6  Virginia papers called (Scott) Rigells campaig...
#
#                                                subject  \
# 0                                       foreign-policy
# 1                                    jobs,labor,unions
# ...

# %%
con_dev1=np.concatenate((feature_1_dev1, feature_2_dev1,feature_3_dev1, feature_4_dev1 ),axis=1)
con_train1=np.concatenate((feature_1_train1, feature_2_train1,feature_3_train1, feature_4_train1),axis=1)
# con_test1=np.concatenate((feature_1_test1,feature_2_test1),axis=1)
y_train=df_train4['label']
# y_test=df_test['score']
y_dev=df_dev4['label']
svr_lin = SVR(kernel="rbf")
svr_lin.fit(con_train1,y_train)
y_pred_dev1=svr_lin.predict(con_dev1)
# y_pred_test1=svr_lin.predict(con_test1)

# %%
df_train2.isnull().sum().sum()
# Out:
# 0

# %%
df_dev4.loc[5734+149]
# Out:
# label                                                                4
# statement            [When I was mayor] Providence was one of the f...
# subject              candidates-biography,city-government,debates,j...
# speaker                                           vincent-buddy-cianci
# party affiliation                                          independent
# Name: 5883, dtype: object

# %%
sc2=f1_score(y_dev,y_pred_dev1,average='macro')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-7eb65ac95cc0> in <module>
# ----> 1 sc2=f1_score(y_dev,y_pred_dev1,average='macro')
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1121     modified with ``zero_division``.
#    1122     """
# -> 1123     return fbeta_score(
#    1124         y_true,
#    1125         y_pred,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1259     """
#    1260
# -> 1261     _, _, f, _ = precision_recall_fscore_support(
#    1262         y_true,
#    1263         y_pred,
#
# ...

# %%
y_pred_dev2=[]
for i in y_pred_dev1:
  y_pred_dev2.append(round(i))

# %%
# y_pred_dev2
sc3=f1_score(y_dev,y_pred_dev2,average='macro')
sc3
# Out:
# 0.10138604815813589

# %%
from sklearn.svm import SVC  
clf = SVC(kernel='linear')
clf.fit(con_train1,y_train)
y_pred_dev5=clf.predict(con_dev1)

# %%
sc4=f1_score(y_dev,y_pred_dev5,average='macro')
sc4
# Out:
# 0.2374985083796435

# %%
sc4=f1_score(y_dev,y_pred_dev5,average='macro')
sc4
# Out:
# 0.24165121980205564

# %%
y_pred_dev5
# Out:
# array([2, 3, 2, ..., 4, 5, 6])

# %%
svr_lin = SVR(kernel="rbf")
svr_lin.fit(con_train1,y_train)
y_pred_dev1=svr_lin.predict(con_dev1)

# %%
df_test
# Out:
#                                               statement  \
# 0     In the last six years of Ciancis administratio...
# 1     The (health reform) legislation which Washingt...
# 2     Says Donald Trump and Marco Rubio opposed Cruz...
# 3     Says the United States has the highest corpora...
# 4     Before President Obama acted in Libya in 2011,...
# ...                                                 ...
# 3067  Ohio has lost more population than every other...
# 3068  Operating a health care exchange would be ille...
# 3069  We have that program where immigrants come her...
# 3070  You can absolutely get a gun if you have sever...
# 3071  Recent international reports show the United S...
#
#                                    subject          speaker  \
# 0     crime,criminal-justice,public-safety     jorge-elorza
# 1                      economy,health-care      rob-portman
# 2                  abortion,federal-budget         ted-cruz
# ...

# %%
def get_feature_model2(data_frame):
  """
  Input a data frame and return the embedding vectors for the each sentence column using model2,
  Return 2 matrices each of shape (#_samples, #size_of_word_emb).
  """
  model1 = SentenceTransformer('all-MiniLM-L6-v2')
  embeddings1 = model1.encode(data_frame['statement'], convert_to_tensor=False)
  embeddings2 = model1.encode(data_frame['subject'], convert_to_tensor=False)
  embeddings3 = model1.encode(data_frame['speaker'], convert_to_tensor=False)
  embeddings4 = model1.encode(data_frame['party affiliation'], convert_to_tensor=False)
  return embeddings1,embeddings2,embeddings3,embeddings4

# %%
df_test['statement'].isnull().sum(),df_test['subject'].isnull().sum(),df_test['speaker'].isnull().sum(),df_test['party affiliation'].isnull().sum()
# Out:
# (0, 1, 1, 1)

# %%
feature_1_dev1, feature_2_dev1,feature_3_dev1, feature_4_dev1 = get_feature_model2(df_test)
con_dev1=np.concatenate((feature_1_dev1, feature_2_dev1,feature_3_dev1, feature_4_dev1 ),axis=1)

# %%
y_pred_dev6=clf.predict(con_dev1)

# %%
df_test["label"] = y_pred_dev6
final_res = df_test[['label', 'id']]
final_res.head()
# Out:
#    label  id
# 0      4   0
# 1      1   1
# 2      2   2
# 3      4   3
# 4      3   4

# %%
final_res.to_csv("F3.csv", index=False)

# %%
def get_feature_model2(data_frame):
  """
  Input a data frame and return the embedding vectors for the each sentence column using model2,
  Return 2 matrices each of shape (#_samples, #size_of_word_emb).
  """
  model1 = SentenceTransformer('all-MiniLM-L6-v2')
  embeddings1 = model1.encode(data_frame['statement'], convert_to_tensor=False)
  embeddings2 = model1.encode(data_frame['subject'], convert_to_tensor=False)
  return embeddings1,embeddings2

# %%
df_train3 = df_train2.sample(frac=1, axis=1).sample(frac=1).reset_index(drop=True)
le=len(df_train2)
df_train4=df_train2[0:int(0.8*le)]
df_dev4=df_train2[int(0.8*le):le]
df_dev4=df_dev4.reset_index(drop=True)
df_train4=df_train4.reset_index(drop=True)

# %%
feature_1_dev1 = get_feature_model2(df_dev4)
feature_1_train1 = get_feature_model2(df_train4)
# # feature_1_test1, feature_2_test1 = get_feature_model2(df_test)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
y_train=df_train4['label']
# y_test=df_test['score']
y_dev=df_dev4['label']
# svr_lin = SVR(kernel="rbf")
# svr_lin.fit(con_train1,y_train)
# y_pred_dev1=svr_lin.predict(con_dev1)
# # y_pred_test1=svr_lin.predict(con_test1)

# %%
# sc2=f1_score(y_dev,y_pred_dev1,average='macro')

# %%
from sklearn.svm import SVC  
clf = SVC(kernel='linear')
clf.fit(feature_1_train1,y_train)
y_pred_dev5=clf.predict(feature_1_dev1)

# %%
sc4=f1_score(y_dev,y_pred_dev5,average='macro')
sc4
# Out:
# 0.22707579837188252

# %%
def get_feature_model2(data_frame):
  """
  Input a data frame and return the embedding vectors for the each sentence column using model2,
  Return 2 matrices each of shape (#_samples, #size_of_word_emb).
  """
  model1 = SentenceTransformer('all-mpnet-base-v2')
  embeddings1 = model1.encode(data_frame['statement'], convert_to_tensor=False)
  embeddings2 = model1.encode(data_frame['subject'], convert_to_tensor=False)
  embeddings3 = model1.encode(data_frame['speaker'], convert_to_tensor=False)
  embeddings4 = model1.encode(data_frame['party affiliation'], convert_to_tensor=False)
  return embeddings1,embeddings2,embeddings3,embeddings4

# %%
# # feature_1_dev1, feature_2_dev1,feature_3_dev1  = get_feature_model2(df_dev4)
# # feature_1_train1, feature_2_train1,feature_3_train1 = get_feature_model2(df_train4)
# # # # feature_1_test1, feature_2_test1 = get_feature_model2(df_test)

# feature_1_dev1, feature_2_dev1,feature_3_dev1, feature_4_dev1 = get_feature_model2(df_test)
# con_dev1=np.concatenate((feature_1_dev1, feature_2_dev1,feature_3_dev1, feature_4_dev1 ),axis=1)

feature_1_dev1, feature_2_dev1,feature_3_dev1, feature_4_dev1 = get_feature_model2(df_dev4)
feature_1_train1, feature_2_train1,feature_3_train1, feature_4_train1 = get_feature_model2(df_train4)
# # feature_1_test1, feature_2_test1 = get_feature_model2(df_test)

# %%
con_dev1=np.concatenate((feature_1_dev1, feature_2_dev1, feature_4_dev1 ),axis=1)
con_train1=np.concatenate((feature_1_train1, feature_2_train1, feature_4_train1),axis=1)
# con_test1=np.concatenate((feature_1_test1,feature_2_test1),axis=1)
y_train=df_train4['label']
# y_test=df_test['score']
y_dev=df_dev4['label']
# svr_lin = SVR(kernel="linear")
# svr_lin.fit(con_train1,y_train)
# y_pred_dev1=svr_lin.predict(con_dev1)
from sklearn.svm import SVC  
clf = SVC(kernel='linear')
clf.fit(con_train1,y_train)
y_pred_dev5=clf.predict(con_dev1)

sc4=f1_score(y_dev,y_pred_dev5,average='macro')
sc4
# Out:
# 0.2543450696017965

# %%
feature_1_dev1, feature_2_dev1,feature_3_dev1, feature_4_dev1 = get_feature_model2(df_test)
con_dev1=np.concatenate((feature_1_dev1,feature_3_dev1, feature_4_dev1 ),axis=1)

# %%
y_pred_dev6=clf.predict(con_dev1)
df_test["label"] = y_pred_dev6
final_res = df_test[['label', 'id']]
final_res.head()
# Out:
#    label  id
# 0      4   0
# 1      1   1
# 2      2   2
# 3      4   3
# 4      4   4

# %%
final_res.to_csv("F3.csv", index=False)
